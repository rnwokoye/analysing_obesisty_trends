# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import gmaps
import os
import json 
import scipy.stats as st
from sklearn.linear_model import LinearRegression
import urllib
from scipy.stats import linregress
import time

# %%
# File to Load
file_to_load = "Resources/BRFSS__Table_of_Overweight_and_Obesity__BMI_.csv"

# Read Obesity CSV and store into Pandas data frame
obesity_df_full = pd.read_csv(file_to_load)
obesity_df_full.head(10)
# Out:
#    Year Locationabbr Locationdesc                         Class  \
# 0  2019           AK       Alaska  Overweight and Obesity (BMI)
# 1  2019           AK       Alaska  Overweight and Obesity (BMI)
# 2  2019           AK       Alaska  Overweight and Obesity (BMI)
# 3  2019           AK       Alaska  Overweight and Obesity (BMI)
# 4  2019           AK       Alaska  Overweight and Obesity (BMI)
# 5  2019           AK       Alaska  Overweight and Obesity (BMI)
# 6  2019           AK       Alaska  Overweight and Obesity (BMI)
# 7  2019           AK       Alaska  Overweight and Obesity (BMI)
# 8  2019           AK       Alaska  Overweight and Obesity (BMI)
# 9  2019           AK       Alaska  Overweight and Obesity (BMI)
#
#             Topic                                           Question  \
# 0  BMI Categories  Weight classification by Body Mass Index (BMI)...
# 1  BMI Categories  Weight classification by Body Mass Index (BMI)...
# 2  BMI Categories  Weight classification by Body Mass Index (BMI)...
# 3  BMI Categories  Weight classification by Body Mass Index (BMI)...
# 4  BMI Categories  Weight classification by Body Mass Index (BMI)...
# 5  BMI Categories  Weight classification by Body Mass Index (BMI)...
# 6  BMI Categories  Weight classification by Body Mass Index (BMI)...
# 7  BMI Categories  Weight classification by Body Mass Index (BMI)...
# 8  BMI Categories  Weight classification by Body Mass Index (BMI)...
# 9  BMI Categories  Weight classification by Body Mass Index (BMI)...
#
#                         Response  \
# 0     Overweight (BMI 25.0-29.9)
# 1    Underweight (BMI 12.0-18.4)
# 2        Obese (BMI 30.0 - 99.8)
# 3     Overweight (BMI 25.0-29.9)
# 4  Normal Weight (BMI 18.5-24.9)
# 5        Obese (BMI 30.0 - 99.8)
# 6     Overweight (BMI 25.0-29.9)
# 7  Normal Weight (BMI 18.5-24.9)
# 8    Underweight (BMI 12.0-18.4)
# 9     Overweight (BMI 25.0-29.9)
#
#                                          Break_Out  Break_Out_Category  \
# 0                              Black, non-Hispanic      Race/Ethnicity
# 1                        Multiracial, non-Hispanic      Race/Ethnicity
# 2                                   H.S. or G.E.D.  Education Attained
# 3                                            35-44           Age Group
# 4                                  $15,000-$24,999    Household Income
# 5                                              65+           Age Group
# 6                                Less than $15,000    Household Income
# 7                                  $25,000-$34,999    Household Income
# 8  American Indian or Alaskan Native, non-Hispanic      Race/Ethnicity
# 9                              Other, non-Hispanic      Race/Ethnicity
#
#   Sample_Size  ...                                Data_Value_Footnote  \
# 0          22  ...  Prevalence estimate not available if the unwei...
# 1           2  ...  Prevalence estimate not available if the unwei...
# 2         239  ...                                                NaN
# 3         151  ...                                                NaN
# 4          95  ...                                                NaN
# 5         261  ...                                                NaN
# 6          49  ...                                                NaN
# 7          48  ...                                                NaN
# 8           5  ...  Prevalence estimate not available if the unwei...
# 9          19  ...  Prevalence estimate not available if the unwei...
#
#    DataSource  ClassId  TopicId LocationID BreakoutID BreakOutCategoryID  \
# 0       BRFSS  CLASS14  TOPIC09          2     RACE02               CAT4
# 1       BRFSS  CLASS14  TOPIC09          2     RACE07               CAT4
# 2       BRFSS  CLASS14  TOPIC09          2     EDUCA2               CAT5
# 3       BRFSS  CLASS14  TOPIC09          2      AGE03               CAT3
# 4       BRFSS  CLASS14  TOPIC09          2    INCOME2               CAT6
# 5       BRFSS  CLASS14  TOPIC09          2      AGE09               CAT3
# 6       BRFSS  CLASS14  TOPIC09          2    INCOME1               CAT6
# 7       BRFSS  CLASS14  TOPIC09          2    INCOME3               CAT6
# 8       BRFSS  CLASS14  TOPIC09          2     RACE03               CAT4
# 9       BRFSS  CLASS14  TOPIC09          2     RACE06               CAT4
#
#   QuestionID ResponseID                               GeoLocation
# 0   _BMI5CAT    RESP040  (64.84507995700051, -147.72205903599973)
# 1   _BMI5CAT    RESP042  (64.84507995700051, -147.72205903599973)
# 2   _BMI5CAT    RESP039  (64.84507995700051, -147.72205903599973)
# 3   _BMI5CAT    RESP040  (64.84507995700051, -147.72205903599973)
# 4   _BMI5CAT    RESP041  (64.84507995700051, -147.72205903599973)
# 5   _BMI5CAT    RESP039  (64.84507995700051, -147.72205903599973)
# 6   _BMI5CAT    RESP040  (64.84507995700051, -147.72205903599973)
# 7   _BMI5CAT    RESP041  (64.84507995700051, -147.72205903599973)
# 8   _BMI5CAT    RESP042  (64.84507995700051, -147.72205903599973)
# 9   _BMI5CAT    RESP040  (64.84507995700051, -147.72205903599973)
#
# [10 rows x 27 columns]

# %%
# Extract Columns that will be used in analysis
reduced_obesity_df = obesity_df_full.loc[:, ["Year", "Locationabbr", "Response", "Break_Out", "Break_Out_Category", 
                                             "Sample_Size", "BreakoutID", "GeoLocation"]]
reduced_obesity_df.head()
# Out:
#    Year Locationabbr                       Response  \
# 0  2019           AK     Overweight (BMI 25.0-29.9)
# 1  2019           AK    Underweight (BMI 12.0-18.4)
# 2  2019           AK        Obese (BMI 30.0 - 99.8)
# 3  2019           AK     Overweight (BMI 25.0-29.9)
# 4  2019           AK  Normal Weight (BMI 18.5-24.9)
#
#                    Break_Out  Break_Out_Category Sample_Size BreakoutID  \
# 0        Black, non-Hispanic      Race/Ethnicity          22     RACE02
# 1  Multiracial, non-Hispanic      Race/Ethnicity           2     RACE07
# 2             H.S. or G.E.D.  Education Attained         239     EDUCA2
# 3                      35-44           Age Group         151      AGE03
# 4            $15,000-$24,999    Household Income          95    INCOME2
#
#                                 GeoLocation
# 0  (64.84507995700051, -147.72205903599973)
# 1  (64.84507995700051, -147.72205903599973)
# 2  (64.84507995700051, -147.72205903599973)
# 3  (64.84507995700051, -147.72205903599973)
# 4  (64.84507995700051, -147.72205903599973)

# %%
# Rename columns for clarity
reduced_obesity_df = reduced_obesity_df.rename(columns={"Locationabbr": "State", 
                                                        "Response": "BMI Range", "Break_Out": "Class", 
                                                        "Break_Out_Category": "Class Category", 
                                                        "Sample_Size": "Number of Respondents",
                                                        "BreakoutID": "Class ID"})

reduced_obesity_df.head()
# Out:
#    Year State                      BMI Range                      Class  \
# 0  2019    AK     Overweight (BMI 25.0-29.9)        Black, non-Hispanic
# 1  2019    AK    Underweight (BMI 12.0-18.4)  Multiracial, non-Hispanic
# 2  2019    AK        Obese (BMI 30.0 - 99.8)             H.S. or G.E.D.
# 3  2019    AK     Overweight (BMI 25.0-29.9)                      35-44
# 4  2019    AK  Normal Weight (BMI 18.5-24.9)            $15,000-$24,999
#
#        Class Category Number of Respondents Class ID  \
# 0      Race/Ethnicity                    22   RACE02
# 1      Race/Ethnicity                     2   RACE07
# 2  Education Attained                   239   EDUCA2
# 3           Age Group                   151    AGE03
# 4    Household Income                    95  INCOME2
#
#                                 GeoLocation
# 0  (64.84507995700051, -147.72205903599973)
# 1  (64.84507995700051, -147.72205903599973)
# 2  (64.84507995700051, -147.72205903599973)
# 3  (64.84507995700051, -147.72205903599973)
# 4  (64.84507995700051, -147.72205903599973)

# %%
# Reorder columns for clairty
reduced_obesity_df = reduced_obesity_df[['Year', 'State', 'Number of Respondents', 
                                         'BMI Range', 'Class', 'Class Category', 'Class ID', 'GeoLocation']]
reduced_obesity_df.head()
# Out:
#    Year State Number of Respondents                      BMI Range  \
# 0  2019    AK                    22     Overweight (BMI 25.0-29.9)
# 1  2019    AK                     2    Underweight (BMI 12.0-18.4)
# 2  2019    AK                   239        Obese (BMI 30.0 - 99.8)
# 3  2019    AK                   151     Overweight (BMI 25.0-29.9)
# 4  2019    AK                    95  Normal Weight (BMI 18.5-24.9)
#
#                        Class      Class Category Class ID  \
# 0        Black, non-Hispanic      Race/Ethnicity   RACE02
# 1  Multiracial, non-Hispanic      Race/Ethnicity   RACE07
# 2             H.S. or G.E.D.  Education Attained   EDUCA2
# 3                      35-44           Age Group    AGE03
# 4            $15,000-$24,999    Household Income  INCOME2
#
#                                 GeoLocation
# 0  (64.84507995700051, -147.72205903599973)
# 1  (64.84507995700051, -147.72205903599973)
# 2  (64.84507995700051, -147.72205903599973)
# 3  (64.84507995700051, -147.72205903599973)
# 4  (64.84507995700051, -147.72205903599973)

# %%
# Split GeoLocation into lat and lng for loop
new_column = reduced_obesity_df["GeoLocation"].str.split(",", n = 1, expand = True) 
reduced_obesity_df["Lat"]= new_column[0] 
reduced_obesity_df["Lng"]= new_column[1] 
reduced_obesity_df.head()
# Out:
#    Year State Number of Respondents                      BMI Range  \
# 0  2019    AK                    22     Overweight (BMI 25.0-29.9)
# 1  2019    AK                     2    Underweight (BMI 12.0-18.4)
# 2  2019    AK                   239        Obese (BMI 30.0 - 99.8)
# 3  2019    AK                   151     Overweight (BMI 25.0-29.9)
# 4  2019    AK                    95  Normal Weight (BMI 18.5-24.9)
#
#                        Class      Class Category Class ID  \
# 0        Black, non-Hispanic      Race/Ethnicity   RACE02
# 1  Multiracial, non-Hispanic      Race/Ethnicity   RACE07
# 2             H.S. or G.E.D.  Education Attained   EDUCA2
# 3                      35-44           Age Group    AGE03
# 4            $15,000-$24,999    Household Income  INCOME2
#
#                                 GeoLocation                 Lat  \
# 0  (64.84507995700051, -147.72205903599973)  (64.84507995700051
# 1  (64.84507995700051, -147.72205903599973)  (64.84507995700051
# 2  (64.84507995700051, -147.72205903599973)  (64.84507995700051
# 3  (64.84507995700051, -147.72205903599973)  (64.84507995700051
# 4  (64.84507995700051, -147.72205903599973)  (64.84507995700051
#
#                      Lng
# 0   -147.72205903599973)
# 1   -147.72205903599973)
# 2   -147.72205903599973)
# 3   -147.72205903599973)
# 4   -147.72205903599973)

# %%
# Remove unwanted characters from the Lat and Lng Columns
reduced_obesity_df['Lat'] = reduced_obesity_df['Lat'].str.replace('(', '')
reduced_obesity_df['Lng'] = reduced_obesity_df['Lng'].str.replace(')', '')

# %%
# Remove Geolocation
reduced_obesity_df = reduced_obesity_df.drop(columns=['GeoLocation'])

# %%
# Remove commas from Number of Respondents
reduced_obesity_df['Number of Respondents'] = reduced_obesity_df['Number of Respondents'].str.replace(',', '')

# %%
# Convert Number of Respondents Columns to integer
reduced_obesity_df['Number of Respondents'] = pd.to_numeric(reduced_obesity_df['Number of Respondents'])
reduced_obesity_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47074 entries, 0 to 47073
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   47074 non-null  int64
#  1   State                  47074 non-null  object
#  2   Number of Respondents  47074 non-null  int64
#  3   BMI Range              47074 non-null  object
#  4   Class                  47074 non-null  object
#  5   Class Category         47074 non-null  object
#  6   Class ID               47074 non-null  object
#  7   Lat                    47002 non-null  object
#  8   Lng                    47002 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 3.2+ MB

# %%
# Keep only most recent year (2019)
recent_df = reduced_obesity_df.loc[reduced_obesity_df['Year'] == 2019]

# %%
# Drop year column
recent_df = recent_df.drop(columns=['Year'])

# %%
# Keep only number of Respondents and BMI Range for state v. state comparison
recent_df_reduced = recent_df.loc[:, ["State", "Number of Respondents", "BMI Range"]]

# %%
# Display max rows
pd.set_option('display.max_rows', None)

# %%
# Display the total number of states
total_states = len(recent_df_reduced["State"].unique())
total_states
# Out:
# 54

# %%
# Drop the US Rows
drop_us = recent_df_reduced.drop(recent_df_reduced.index[4680:4684])

# %%
# Drop the UW Rows
drop_uw = drop_us.drop(recent_df_reduced.index[4788:4792])

# %%
# Reset index and Rename DF
clean_state_df = drop_uw.reset_index(drop=True)

# %%
# Check new length of states (should be 52, 50 states plus PR and Guam)
new_total_states = len(clean_state_df["State"].unique())
new_total_states
# Out:
# 52

# %%
# Display the total number of respondents
respondent_total = clean_state_df["Number of Respondents"].sum()
respondent_total
# Out:
# 2231286

# %%
# Get sum of total respondents for each state
state_sum = clean_state_df.groupby('State')['Number of Respondents'].sum()

# Get sum of total overweight respondents for each state
overweight_sum = clean_state_df.loc[clean_state_df["BMI Range"] == 'Overweight (BMI 25.0-29.9)'].groupby("State")["Number of Respondents"].sum()

# Find overweight rates for each state
overweight_rates = (overweight_sum / state_sum) * 100

# Get sum of total underweight respondents for each state
underweight_sum = clean_state_df.loc[clean_state_df["BMI Range"] == 'Underweight (BMI 12.0-18.4)'].groupby("State")["Number of Respondents"].sum()

# Find underweight rates for each state
underweight_rates = (underweight_sum / state_sum) * 100

# Get sum of total obese respondents for each state
obesity_sum = clean_state_df.loc[clean_state_df["BMI Range"] == 'Obese (BMI 30.0 - 99.8)'].groupby("State")["Number of Respondents"].sum()

# Find obesity rates for each state
obesity_rates = (obesity_sum / state_sum) * 100

# Get sum of total normalweight respondents for each state
normal_sum = clean_state_df.loc[clean_state_df["BMI Range"] == 'Normal Weight (BMI 18.5-24.9)'].groupby("State")["Number of Respondents"].sum()

# Find Obesity Rates for each state
normal_rates = (normal_sum / state_sum) * 100

# %%
# Create New Data Frame to hold the values

state_summary_df = pd.DataFrame({
                                "% Overweight": overweight_rates,
                                "% Underweight": underweight_rates,
                                "% Obese": obesity_rates,
                                "% Normal": normal_rates
                                                        })
state_summary_df.style.format({
                                "% Overweight":"{:,.2f}",
                                "% Underweight": "{:,.2f}",
                                "% Obese": "{:,.2f}",
                                "% Normal": "{:,.2f}"
                                   })
# Out:
# <style  type="text/css" >
# </style><table id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >% Overweight</th>        <th class="col_heading level0 col1" >% Underweight</th>        <th class="col_heading level0 col2" >% Obese</th>        <th class="col_heading level0 col3" >% Normal</th>    </tr>    <tr>        <th class="index_name level0" >State</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024level0_row0" class="row_heading level0 row0" >AK</th>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row0_col0" class="data row0 col0" >36.34</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row0_col1" class="data row0 col1" >1.56</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row0_col2" class="data row0 col2" >30.83</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row0_col3" class="data row0 col3" >31.27</td>
#             </tr>
#             <tr>
#                         <th id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024level0_row1" class="row_heading level0 row1" >AL</th>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row1_col0" class="data row1 col0" >35.22</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row1_col1" class="data row1 col1" >1.96</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row1_col2" class="data row1 col2" >35.99</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row1_col3" class="data row1 col3" >26.84</td>
#             </tr>
#             <tr>
#                         <th id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024level0_row2" class="row_heading level0 row2" >AR</th>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row2_col0" class="data row2 col0" >34.36</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row2_col1" class="data row2 col1" >1.54</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row2_col2" class="data row2 col2" >35.27</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row2_col3" class="data row2 col3" >28.83</td>
#             </tr>
#             <tr>
#                         <th id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024level0_row3" class="row_heading level0 row3" >AZ</th>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row3_col0" class="data row3 col0" >35.95</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row3_col1" class="data row3 col1" >1.99</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row3_col2" class="data row3 col2" >30.06</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row3_col3" class="data row3 col3" >32.00</td>
#             </tr>
#             <tr>
#                         <th id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024level0_row4" class="row_heading level0 row4" >CA</th>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row4_col0" class="data row4 col0" >37.18</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row4_col1" class="data row4 col1" >1.71</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row4_col2" class="data row4 col2" >27.05</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row4_col3" class="data row4 col3" >34.05</td>
#             </tr>
#             <tr>
#                         <th id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024level0_row5" class="row_heading level0 row5" >CO</th>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row5_col0" class="data row5 col0" >36.54</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row5_col1" class="data row5 col1" >1.89</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row5_col2" class="data row5 col2" >24.10</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row5_col3" class="data row5 col3" >37.47</td>
#             </tr>
#             <tr>
#                         <th id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024level0_row6" class="row_heading level0 row6" >CT</th>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row6_col0" class="data row6 col0" >37.97</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row6_col1" class="data row6 col1" >1.69</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row6_col2" class="data row6 col2" >28.13</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row6_col3" class="data row6 col3" >32.21</td>
#             </tr>
#             <tr>
#                         <th id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024level0_row7" class="row_heading level0 row7" >DC</th>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row7_col0" class="data row7 col0" >34.00</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row7_col1" class="data row7 col1" >1.30</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row7_col2" class="data row7 col2" >27.35</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row7_col3" class="data row7 col3" >37.35</td>
#             </tr>
#             <tr>
#                         <th id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024level0_row8" class="row_heading level0 row8" >DE</th>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row8_col0" class="data row8 col0" >35.34</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row8_col1" class="data row8 col1" >1.67</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row8_col2" class="data row8 col2" >35.53</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row8_col3" class="data row8 col3" >27.46</td>
#             </tr>
#             <tr>
#                         <th id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024level0_row9" class="row_heading level0 row9" >FL</th>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row9_col0" class="data row9 col0" >35.99</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row9_col1" class="data row9 col1" >2.24</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row9_col2" class="data row9 col2" >30.93</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row9_col3" class="data row9 col3" >30.84</td>
#             </tr>
#             <tr>
#                         <th id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024level0_row10" class="row_heading level0 row10" >GA</th>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row10_col0" class="data row10 col0" >34.44</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row10_col1" class="data row10 col1" >2.09</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row10_col2" class="data row10 col2" >33.73</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row10_col3" class="data row10 col3" >29.75</td>
#             </tr>
#             <tr>
#                         <th id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024level0_row11" class="row_heading level0 row11" >GU</th>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row11_col0" class="data row11 col0" >36.40</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row11_col1" class="data row11 col1" >1.96</td>
#                         <td id="T_c9f0a0e0_82b9_11eb_9afc_fc017c065024row11_col2" class="data row11 col2" >30.64</td>
#                         <td id="T_c9f0a0e0_82b9_1

# %%
# Create Bar Graph Representing Overweight Rates
x_axis = recent_df_reduced['State'].unique()
y_axis = overweight_rates
state_obesity_bar = y_axis.plot(kind="bar", figsize=(15,5), title="2019 Overweight Rates by State")
state_obesity_bar.set_xlabel("State")
state_obesity_bar.set_ylabel("Overweight Rates: BMI 25.0-29.9")
# Out:
# Text(0, 0.5, 'Overweight Rates: BMI 25.0-29.9')

# %%
# Create Bar Graph Representing Underweight Rates
x_axis = recent_df_reduced['State'].unique()
y_axis = underweight_rates
state_obesity_bar = y_axis.plot(kind="bar", figsize=(15,5), title="2019 Underweight Rates by State")
state_obesity_bar.set_xlabel("State")
state_obesity_bar.set_ylabel("Underweight Rates: BMI 12.0-18.4")
# Out:
# Text(0, 0.5, 'Underweight Rates: BMI 12.0-18.4')

# %%
# Create Bar Graph Representing Obesity Rates
x_axis = recent_df_reduced['State'].unique()
y_axis = obesity_rates
state_obesity_bar = y_axis.plot(kind="bar", figsize=(15,5), title="2019 Obesity Rates by State")
state_obesity_bar.set_xlabel("State")
state_obesity_bar.set_ylabel("Obesity Rates: BMI 30.0 - 99.8")
# Out:
# Text(0, 0.5, 'Obesity Rates: BMI 30.0 - 99.8')

# %%
# Create Bar Graph Representing Obesity Rates
x_axis = recent_df_reduced['State'].unique()
y_axis = normal_rates
state_obesity_bar = y_axis.plot(kind="bar", figsize=(15,5), title="2019 Normal Weight Rates by State")
state_obesity_bar.set_xlabel("State")
state_obesity_bar.set_ylabel("Normal Weight: BMI 18.5-24.9")
# Out:
# Text(0, 0.5, 'Normal Weight: BMI 18.5-24.9')
